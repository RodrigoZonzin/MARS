# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys
import atproto as bsk
from senha import senha

# %%
#pip install atproto
#Login: tpmars2@gmail.com

# %%
client = bsk.Client()

client.login('tpmars.bsky.social', senha)
# Out:
# ---------------------------------------------------------------------------
# UnauthorizedError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 client = bsk.Client()
# ----> 3 client.login('tpmars.bsky.social', senha)
#
# File ~/.local/lib/python3.12/site-packages/atproto_client/client/client.py:102, in Client.login(self, login, password, session_string, auth_factor_token)
#     100     session = self._import_session_string(session_string)
#     101 elif login and password:
# --> 102     session = self._get_and_set_session(login, password, auth_factor_token)
#     103 else:
#     104     raise ValueError('Either session_string or login and password should be provided.')
#
# File ~/.local/lib/python3.12/site-packages/atproto_client/client/client.py:49, in Client._get_and_set_session(self, login, password, auth_factor_token)
#      46 def _get_and_set_session(
# ...
