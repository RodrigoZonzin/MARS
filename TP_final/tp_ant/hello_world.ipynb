# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys
import atproto as bsk
import networkx as nx
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from senha import senha

# %%
#pip install atproto
#Login: tpmars2@gmail.com

# %%
client = bsk.Client()

client.login('tpmars.bsky.social', 'ViniVini@123')
# Out:
# ProfileViewDetailed(did='did:plc:ccvg46rdila3t6zlietwi6qe', handle='tpmars.bsky.social', associated=ProfileAssociated(chat=None, feedgens=0, labeler=False, lists=0, starter_packs=0, py_type='app.bsky.actor.defs#profileAssociated', activitySubscription={'allowSubscriptions': 'followers'}), avatar='https://cdn.bsky.app/img/avatar/plain/did:plc:ccvg46rdila3t6zlietwi6qe/bafkreidsdfe4gtx2ayfomg3xjdxbugo3dsejdgsm2qrpti25mqbyrnmyhu@jpeg', banner=None, created_at='2025-07-10T18:22:57.932Z', description=None, display_name='', followers_count=1, follows_count=1, indexed_at='2025-07-10T18:22:57.932Z', joined_via_starter_pack=None, labels=[], pinned_post=None, posts_count=0, verification=None, viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=None, muted=False, muted_by_list=None, py_type='app.bsky.actor.defs#viewerState'), py_type='app.bsky.actor.defs#profileViewDetailed')

# %%
search = client.app.bsky.feed.search_posts({'q': '#BrasilSoberano'})

# %%
comentarios = [el.record.text for el in dict(search)['posts']]

# %%
nomes_usuarios = [el.author['handle'] for el in dict(search)['posts']]

# %%
df = pd.DataFrame(columns = ['handle', 'comentarios', 'sentimento'])

# %%
df['handle'] = nomes_usuarios
df['comentarios'] = comentarios

# %%
analyzer = SentimentIntensityAnalyzer()

sentimentos = [analyzer.polarity_scores(txt) for txt in df['comentarios'] ]

# %%
def parseSentimento(sentimento): 
    return max

sentimentos[0]
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
df
# Out:
#                             handle  \
# 0       trendingbrasil.bsky.social
# 1           followlori.bsky.social
# 2              acm2205.bsky.social
# 3              mariajo.bsky.social
# 4           juliopires.bsky.social
# 5           mirian1970.bsky.social
# 6           mirian1970.bsky.social
# 7          diegogaroto.bsky.social
# 8             almofrey.bsky.social
# 9             almofrey.bsky.social
# 10  diegogarotooficial.bsky.social
# 11            almofrey.bsky.social
# 12           zelafneto.bsky.social
# 13          cjmedeiros.bsky.social
# 14      trendingbrasil.bsky.social
# 15          mirian1970.bsky.social
# 16             silmarq.bsky.social
# 17          cjmedeiros.bsky.social
# 18               oswal.bsky.social
# 19          cjmedeiros.bsky.social
# 20          mirian1970.bsky.social
# 21     rafaelguerreiro.bsky.social
# 22          marceloudr.bsky.social
# 23              dauraj.bsky.social
# 24         gabiaraujoo.bsky.social
#
# ...

# %%
g = nx.DiGraph()

g.add_nodes_from(df['handle'])

# %%
nx.draw(g)

# %%
seguidores = bsk.get_followers('acm2205.bsky.social')

# %%
df
# Out:
#                             handle
# 0       trendingbrasil.bsky.social
# 1           followlori.bsky.social
# 2              acm2205.bsky.social
# 3              mariajo.bsky.social
# 4           juliopires.bsky.social
# 5           mirian1970.bsky.social
# 6           mirian1970.bsky.social
# 7          diegogaroto.bsky.social
# 8             almofrey.bsky.social
# 9             almofrey.bsky.social
# 10  diegogarotooficial.bsky.social
# 11            almofrey.bsky.social
# 12           zelafneto.bsky.social
# 13          cjmedeiros.bsky.social
# 14      trendingbrasil.bsky.social
# 15          mirian1970.bsky.social
# 16             silmarq.bsky.social
# 17          cjmedeiros.bsky.social
# 18               oswal.bsky.social
# 19          cjmedeiros.bsky.social
# 20          mirian1970.bsky.social
# 21     rafaelguerreiro.bsky.social
# 22          marceloudr.bsky.social
# 23              dauraj.bsky.social
# 24         gabiaraujoo.bsky.social
